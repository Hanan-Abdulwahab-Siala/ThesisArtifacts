# %%
"""
Based on: Philipp Schmid's code (https://github.com/philschmid/deep-learning-pytorch-huggingface/blob/main/training/scripts/run_fsdp_qlora.py)
Modified by: Hanan Abdulwahab Siala, King's College London
Date: 2020-10-05

Description:
    This program fine-tunes on 4 GPUs to construct OCL specifications from both Java and Python programs ( main program ).
"""

# %%
# 4 GPUs

import torch
torch.cuda.empty_cache()  

# !pip cache purge
# !ACCELERATE_USE_FSDP=1 FSDP_CPU_RAM_EFFICIENT_LOADING=1 torchrun --nproc_per_node=4 /users/k20122072/Fine-tuning-4-GPUs.py

# %%
# Resume 4 GPUs 

import torch
torch.cuda.empty_cache() 

# !pip cache purge
# !ACCELERATE_USE_FSDP=1 FSDP_CPU_RAM_EFFICIENT_LOADING=1 \
torchrun --nproc_per_node=4 /users/k20122072/Fine-tuning-4-GPUs.py \
  --resume_from_checkpoint /scratch/users/k20122072/Mistral-7B-PythonOCLB/checkpoint-1105
